# %% [markdown]
# # Enunciado

# %% [markdown]
# ![Screenshot 2023-02-15 104904.png](data:image/png;base64,...)

# %% [markdown]
# # Laboratorio

# %%
# from google.colab import drive
# drive.mount('/content/drive/MyDrive/IA/Lab06')

# %% [markdown]
# ## 1. Generación del set de datos de 100 mil datos

# %%
import numpy as np
import matplotlib.pyplot as plt

# Generar conjunto de datos
x = np.random.rand(100000)
y = 45.45*x + 1.78

print(x.shape)
print(y.shape)
# Out:
# (100000,)
# (100000,)

# %%
def generateDataset():

# %% [markdown]
# ## 2. Algoritmo de Regresión de Lineal

# %%
def calculate_b(x_mean, y_mean, x, y):
    num = 0
    den = 0
    for i in range(len(x)):
        num += (x[i] - x_mean) * (y[i] - y_mean)
        den += (x[i] - x_mean) ** 2
    b = num / den
    return b

def calculate_a(x_mean, y_mean, b):
    a = y_mean - (b * x_mean)
    
    return a

def calculate_means(x, y):
    x_mean = np.mean(x)
    `-----------y_mean = np.mean(y)
    return x_mean, y_mean


x_mean, y_mean = calculate_means(x, y)
b = calculate_b(x_mean, y_mean, x, y)
a = calculate_a(x_mean, y_mean, b)

print("a = ", a)
print("b = ", b)
# Out:
# a =  1.7800000000001681
# b =  45.449999999999676

# %% [markdown]
# ## 3.

# %% [markdown]
# ## 4. Graficación de las observaciones en 2D

# %%
# Graficar conjunto de datos
plt.scatter(x, y, s=1)

# Agregar etiquetas a los ejes y un título al gráfico
plt.xlabel('x')
plt.ylabel('y')
plt.title('Conjunto de datos con comportamiento lineal')

# Mostrar el gráfico
plt.show()

# %% [markdown]
# ## 5.

# %% [markdown]
# ## 6.
